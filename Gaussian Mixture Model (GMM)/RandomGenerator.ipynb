# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  

N = 10000
X0 = np.random.rand(N)
X1 = 3*X0
Y  = np.power(9*X1, 1.0/3)

t = np.arange(0.0, 3.0, 0.01)
y = t*t/9
 
plt.plot(t, y, 'r-', linewidth=1)
plt.hist(Y, bins=50, normed=1, facecolor='green', alpha=0.75)
plt.show()

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

count, bins, ignored = plt.hist(s, 30, normed=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) ), linewidth=2, color='r')
plt.show()

# %%
points = np.random.normal(size=[1000, 2])
plt.plot(points[:, 0], points[:, 1], 'ro')
plt.show()

# %%
points = np.random.binomial(100, 0.5, 10)
print points
# Out:
# [52 47 48 55 53 50 51 49 50 57]
